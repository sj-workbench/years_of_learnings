# %% [markdown]
# <a href="https://colab.research.google.com/github/sj-workbench/years_of_learnings/blob/main/rr_gradientdescent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_diabetes
from sklearn.metrics import r2_score
import numpy as pd

# %%
x,y = load_diabetes(return_X_y=True)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=4)

# %%
from sklearn.linear_model import SGDRegressor

# %%
reg = SGDRegressor(penalty = 'l2', max_iter=500, eta0 = 0.1, learning_rate='constant', alpha = 0.01)

# %%
reg.fit(x_train,y_train)
y_pred = reg.predict(x_test)
print(r2_score(y_pred,y_test))
print(reg.coef_)
print(reg.intercept_)
# Out:
# -7.624912429306892
# [ 37.32347812 -20.53092836 134.98332716 105.89588941  30.24635857
#   14.65314486 -81.54052338  82.61882925 131.60947137  69.29544178]
# [148.86739583]
