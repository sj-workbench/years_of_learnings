# %% [markdown]
# <a href="https://colab.research.google.com/github/sj-workbench/years_of_learnings/blob/main/gd_ownclass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
import numpy as np
import matplotlib.pyplot as plt

# %%
x,y = make_regression(n_samples = 100, n_features=1, n_informative = 1 , n_targets = 1,noise = 20, random_state = 42)

# %%
plt.scatter(x,y)

# %%
lr = LinearRegression()
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([47.13323967])

# %%
lr.intercept_
# Out:
# np.float64(2.3302306410539453)

# %%
m = 47.13

# %%
class GDregressor:
  def __init__(self,learning_rate=0.001,epochs=10000):
    self.m = 47.13
    self.b = -120
    self.learning_rate = learning_rate
    self.epochs = epochs
  def fit(self,x,y):
    # Calculating GD
    n = len(x)
    for i in range(self.epochs):
      loss_slope = -(2/n)* np.sum(y-self.m*x.ravel() - self.b)
      self.b = self.b - (self.learning_rate*loss_slope)
      print(self.b)

# %%
gd = GDregressor()
gd.fit(x,y)
# Out:
# Streaming output truncated to the last 5000 lines.
# 2.3244067752525974
# 2.3244177501273824
# 2.3244287030524178
# 2.324439634071603
# 2.32445054322875
# 2.324461430567583
# 2.324472296131738
# 2.3244831399647645
# 2.3244939621101253
# 2.324504762611195
# 2.3245155415112633
# 2.324526298853531
# 2.3245370346811143
# 2.3245477490370425
# 2.3245584419642586
# 2.3245691135056203
# 2.324579763703899
# 2.3245903926017815
# 2.324601000241868
# 2.324611586666675
# 2.3246221519186316
# 2.3246326960400845
# 2.3246432190732946
# 2.3246537210604385
# 2.324664202043608
# 2.324674662064811
# 2.3246851011659717
# 2.3246955193889303
# 2.324705916775443
# 2.324716293367182
# 2.324726649205738
# 2.324736984332617
# 2.324747298789242
# 2.324757592616954
# 2.3247678658570106
# 2.324778118550587
# 2.324788350738776
# 2.324798562462589
# 2.324808753762954
# 2.3248189246807183
# 2.324829075256647
# 2.3248392055314238
# 2.3248493155456513
# 2.32485940533985
# 2.3248694749544607
# 2.324879524429842
# ...
