# %% [markdown]
# <a href="https://colab.research.google.com/github/sj-workbench/years_of_learnings/blob/main/random_imputation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Worked on handling missing data with Random Imputation means filling missing values with similar data in the respective column.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('/content/Titanic-Dataset.csv',usecols = ['Age', 'Fare','Survived'])
df.head()
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %%
df.isnull().mean()*100
# Out:
# Survived     0.00000
# Age         19.86532
# Fare         0.00000
# dtype: float64

# %%
x= df.drop(columns = ['Survived'],axis=1)
y = df['Survived']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
# to show before imputation and after imputation
x_train['Age_imputed'] = x_train['Age']
x_test['Age_imputed'] = x_test['Age']

# %%
x_train
# Out:
#       Age      Fare  Age_imputed
# 30   40.0   27.7208         40.0
# 10    4.0   16.7000          4.0
# 873  47.0    9.0000         47.0
# 182   9.0   31.3875          9.0
# 876  20.0    9.8458         20.0
# ..    ...       ...          ...
# 534  30.0    8.6625         30.0
# 584   NaN    8.7125          NaN
# 493  71.0   49.5042         71.0
# 527   NaN  221.7792          NaN
# 168   NaN   25.9250          NaN
#
# [712 rows x 3 columns]

# %%
x_train['Age_imputed'][x_train['Age_imputed'].isnull()]
# Out:
# 77    NaN
# 868   NaN
# 334   NaN
# 295   NaN
# 792   NaN
#        ..
# 674   NaN
# 466   NaN
# 584   NaN
# 527   NaN
# 168   NaN
# Name: Age_imputed, Length: 148, dtype: float64

# %%
x_train['Age'].dropna().sample(x_train['Age'].isnull().sum()).values
# Out:
# array([34.  , 30.  , 21.  , 22.  , 42.  , 51.  , 30.  , 33.  , 36.  ,
#        44.  , 24.  , 36.  , 39.  , 52.  , 21.  , 26.  , 38.  , 20.  ,
#        37.  , 35.  , 27.  , 18.  , 18.  , 24.  ,  4.  , 33.  , 34.  ,
#        44.  , 30.  , 30.  , 20.  , 43.  , 30.  , 52.  , 50.  , 30.  ,
#        54.  ,  0.67, 47.  , 16.  , 53.  , 17.  , 42.  , 22.  , 39.  ,
#        28.  ,  0.42, 24.  , 34.  , 27.  ,  0.75, 19.  , 20.  , 30.5 ,
#        45.  , 58.  , 39.  , 27.  , 25.  , 32.  ,  9.  , 33.  , 36.  ,
#         3.  , 11.  , 29.  , 28.5 , 17.  , 31.  , 21.  , 37.  , 49.  ,
#        17.  , 23.  , 14.  , 16.  , 30.  , 58.  , 21.  , 20.  ,  4.  ,
#        25.  , 31.  , 31.  , 27.  ,  1.  , 28.  , 22.  , 26.  , 27.  ,
#        18.  , 26.  , 23.  , 58.  , 42.  , 60.  , 18.  , 34.  , 47.  ,
#        33.  , 35.  , 44.  , 38.  , 21.  , 19.  , 26.  , 32.5 , 21.  ,
#        30.  , 33.  ,  2.  , 47.  , 32.  , 43.  , 23.  , 47.  , 22.  ,
# ...

# %%
x_train['Age_imputed'][x_train['Age_imputed'].isnull()] = x_train['Age'].dropna().sample(x_train['Age'].isnull().sum()).values
# Out:
# /tmp/ipykernel_622/746893882.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_train['Age_imputed'][x_train['Age_imputed'].isnull()] = x_train['Age'].dropna().sample(x_train['Age'].isnull().sum()).values

# %%
x_test['Age_imputed'][x_test['Age_imputed'].isnull()] = x_test['Age'].dropna().sample(x_test['Age'].isnull().sum()).values
# Out:
# /tmp/ipykernel_622/3885208445.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_test['Age_imputed'][x_test['Age_imputed'].isnull()] = x_test['Age'].dropna().sample(x_test['Age'].isnull().sum()).values

# %%
x_train
# Out:
#       Age      Fare  Age_imputed
# 30   40.0   27.7208        40.00
# 10    4.0   16.7000         4.00
# 873  47.0    9.0000        47.00
# 182   9.0   31.3875         9.00
# 876  20.0    9.8458        20.00
# ..    ...       ...          ...
# 534  30.0    8.6625        30.00
# 584   NaN    8.7125         0.83
# 493  71.0   49.5042        71.00
# 527   NaN  221.7792        35.00
# 168   NaN   25.9250        30.50
#
# [712 rows x 3 columns]

# %%
sns.distplot(x_train['Age'],label = 'Original',hist = False)
sns.distplot(x_train['Age_imputed'],label = 'Imputed', hist = False)

plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_622/3884874494.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x_train['Age'],label = 'Original',hist = False)
# /tmp/ipykernel_622/3884874494.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
print("Originl: ",x_train['Age'].var())
print("Variance: ", x_train['Age_imputed'].var())
# Out:
# Originl:  204.3495133904614
# Variance:  206.07989326553832

# %%
x_train[['Fare','Age','Age_imputed']].cov()
# Out:
#                     Fare         Age  Age_imputed
# Fare         2368.246832   71.512440    60.200966
# Age            71.512440  204.349513   204.349513
# Age_imputed    60.200966  204.349513   206.079893

# %%
x_train[['Age','Age_imputed']].boxplot()
# Out:
# <Axes: >
