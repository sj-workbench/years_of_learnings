# %% [markdown]
# <a href="https://colab.research.google.com/github/sj-workbench/years_of_learnings/blob/main/p_a_n_d_a_s5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# Series

# %%
# String
countries = ['india', 'usa', ' japan','nepal','south korea']
pd.Series(countries[2])
# Out:
# 0     japan
# dtype: object

# %%
# Integer
runs = [32,100,22,1000,567]
pd.Series(runs[3])
# Out:
# 0    1000
# dtype: int64

# %%
# Custom index
gender = ["male","female","male","female","male"]
genders = pd.Series(gender,index=["a","b","c","d","e"])
genders
# Out:
# a      male
# b    female
# c      male
# d    female
# e      male
# dtype: object

# %%
# setting a name
gender_name = pd.Series(gender,index=["a","b","c","d","e"], name = 'GENDER')

# %%
# series from dict
marks = {
    'math':67,
    'english':57,
    'odia': 99,
    "japanese": 37
}
mark_series = pd.Series(marks, name ="MARKS")
mark_series
# Out:
# math        67
# english     57
# odia        99
# japanese    37
# Name: MARKS, dtype: int64

# %%
# series attributes
# size
mark_series.size  # counts missing values
# dtype
genders.dtype
# name
gender_name.name
# is unique
gender_name.is_unique  # gives repetation of items as true or false
# index
mark_series.index
# values
mark_series.values
gender_name.values[0]
# Out:
# 'male'

# %%
# series using read_csv
# with one column
data = pd.read_csv("/content/car data.csv").squeeze()
car_name = data['Car_Name']
type(car_name)
car_name.head()
# two columns
placement = pd.read_csv("/content/placement.csv", index_col = 'cgpa').squeeze()
placement.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_6716/1608719321.py in <cell line: 0>()
#       1 # series using read_csv
#       2 # with one column
# ----> 3 data = pd.read_csv("/content/car data.csv").squeeze()
#       4 car_name = data['Car_Name']
#       5 type(car_name)
#
# ...

# %%
# Series methods
# head and tail
placement.head()
car_name.tail()
# sample
placement.sample(5)
# value counts
placement.value_counts().sample()
# sort_values
placement.sort_values(ascending=False).head()   # ascending and descending available, default = True
# sort_index
car_name.sort_index()

# %%
# Series maths method
# count
placement.count()  # doesnt count missing values
# sum
placement.sum()
# product
placement.product()
# mean
placement.mean()
# median
placement.median()
# std
placement.std()
# min
placement.min()
# max
placement.max()
# describe
placement.describe()     # gives a overview data of data

# %%
# Series indexing

# %%
numbers = [12,23,45,64,'SJ']
numbers = pd.Series(numbers, index = ['a','b','c','d','e'], name = "AGE")
numbers[-1]                        # -ve/+ve works
# Out:
# /tmp/ipykernel_6716/2207923887.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   numbers[-1]                        # -ve/+ve works
# 'SJ'

# %%
number = pd.Series([12,'SJ',42,43,21], name = 'House')
number[1]                        # +ve only works
# Out:
# 'SJ'

# %%
# Series slicing
place = ['japan','south korea', 'LA','London', 'India','Spain', 'Europe','Thailand']
places = pd.Series(place, index = [1,2,3,4,5,6,7,8])
places
place[5::2]
place[::2]
# Out:
# 1          japan
# 2    south korea
# 3             LA
# 4         London
# 5          India
# 6          Spain
# 7         Europe
# 8       Thailand
# dtype: object

# %%
# fancy indexing
places[[1,4,5]]
# Out:
# 1     japan
# 4    London
# 5     India
# dtype: object

# %%
# Editng item inside series
# using indexing
marks = [23,45,65,78,99,76,54]
marks = pd.Series(marks, name = 'mark')
marks[1] = 100   # edited
marks
# what if an index doesnt not exist
marks[7] = 288
marks
# with slicing
marks[2:5:2] = [75,89]
marks
# with fancy indexing
marks[[0,1,2]] = [0,0,0]
marks
# Out:
# 0      0
# 1      0
# 2      0
# 3     78
# 4     89
# 5     76
# 6     54
# 7    288
# Name: mark, dtype: int64

# %%
# Series with python functionalities
# type/dir/len/sorted/max/min
print(len(marks))
print(type(marks))
print(dir(marks))
print(sorted(marks))
print(min(marks))
print(max(marks))

# type conversion
list(marks)
dict(marks)

# membership operator
9 in marks     # used index only
76 in marks.values   # used for values

# loop
for i in marks.index:
  print(i)        # runs on values only but for index use .index

# operators
# Arithmetic operatorss
100 - marks   # example of broadcasting
new_marks = marks + 2
new_marks
# relational operators
marks<10    # boolean series
marks>100
# Out:
# 8
# <class 'pandas.core.series.Series'>
# ...

# %%
# plotting on series
marks.plot()
marks.plot(kind = 'bar')
marks.plot(kind = 'pie')
# Out:
# <Axes: ylabel='mark'>

# %% [markdown]
# DATAFRAMES

# %%
import numpy as np
import pandas as pd

# %%
students = [[100,90,7],[120,89,14],[96,45,89]]
students = pd.DataFrame(students, columns = ['iq','marks','lpa'])       # manual
students.dtypes
# Out:
# iq       int64
# marks    int64
# lpa      int64
# dtype: object

# %%
students_data = {
    'iq':[100,120,96],
    'marks':[90,89,45],
    'lpa':[7,14,89]
}                                                          # dictionary
pd.DataFrame(students_data, index = ['a','b','c'])
# Out:
#     iq  marks  lpa
# a  100     90    7
# b  120     89   14
# c   96     45   89

# %%
placement = pd.read_csv("/content/placement.csv")
placement.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_7259/2085196343.py in <cell line: 0>()
# ----> 1 placement = pd.read_csv("/content/placement.csv")
#       2 placement.head(10)
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
# Dataframe attributes and methods
# shape
placement.shape
# dtypes
placement.dtypes
# index
placement.index
# columns
placement.columns
# values
placement.values
# head and tail
# sample
# info
placement.info()
# describe
placement.describe()
# isnull
placement.isnull().sum()     # false = no missing value   # .sum() represents in each column how many missing values
# duplicated
placement.duplicated().sum()   # .sum() represents no of duplicate value, false represents that particular row is not duplicated
# rename
placement.rename(columns = {'cgpa': 'CGPA'}, inplace = True)   # inplace ensure that changes are permanent
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7259/3802112319.py in <cell line: 0>()
#       1 # Dataframe attributes and methods
#       2 # shape
# ----> 3 placement.shape
#       4 # dtypes
#       5 placement.dtypes
#
# NameError: name 'placement' is not defined

# %%
# maths methods
# sum
placement['CGPA'].sum()
# product
placement.product(axis = 1)  # 1 is sum row-wise, 0 is sum column wise
# mean
placement.mean()
# median
placement.median()
# std
placement.std()
# min
placement.min()
# max
placement.max()
# describe
placement.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7259/3224791381.py in <cell line: 0>()
#       1 # maths methods
#       2 # sum
# ----> 3 placement['CGPA'].sum()
#       4 # product
#       5 placement.product(axis = 1)  # 1 is sum row-wise, 0 is sum column wise
#
# NameError: name 'placement' is not defined

# %%
# selecting columns from dataframe
# single column
placement['CGPA']   # series
# multiple columns
placement[['CGPA','package']]   # dataframe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7259/2055069044.py in <cell line: 0>()
#       1 # selecting columns from dataframe
#       2 # single column
# ----> 3 placement['CGPA']   # series
#       4 # multiple columns
#       5 placement[['CGPA','package']]   # dataframe
#
# NameError: name 'placement' is not defined

# %%
# selecting row from dataframe
# iloc = searches using index  position
# loc  = searches using index labels

# single row
placement['package'].iloc[0:10:2]
# multiple rows
placement[['package','CGPA']].iloc[1]
# fancy indexing
placement.iloc[[0,1,189]]

# loc
# single row
placement.loc[32]     # can used names if given
placement.loc[1:10]    # in loc last one is also included
placement.loc[1:10:2]
# multiple rows
placement[['CGPA','package']].loc[23:26]
# fancy indexing
placement.loc[[1,2,3]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7259/2525575859.py in <cell line: 0>()
#       4
#       5 # single row
# ----> 6 placement['package'].iloc[0:10:2]
#       7 # multiple rows
#       8 placement[['package','CGPA']].iloc[1]
#
# NameError: name 'placement' is not defined

# %%
# selecting both rows and columns
students.iloc[0:2,0:3]    # (Rows:columns)
students.loc[0:1,'iq':'lpa']
# Out:
#     iq  marks  lpa
# 0  100     90    7
# 1  120     89   14

# %%
ipl = pd.read_csv('/content/IPL.csv')
ipl
# Out:
# /tmp/ipykernel_7259/4195225732.py:1: DtypeWarning: Columns (28,29,30,31,43,46,47,48,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   ipl = pd.read_csv('/content/IPL.csv')
#         Unnamed: 0  match_id        date match_type             event_name  \
# 0           141607    335982  2008-04-18        T20  Indian Premier League
# 1           141608    335982  2008-04-18        T20  Indian Premier League
# 2           141609    335982  2008-04-18        T20  Indian Premier League
# 3           141610    335982  2008-04-18        T20  Indian Premier League
# 4           141611    335982  2008-04-18        T20  Indian Premier League
# ...            ...       ...         ...        ...                    ...
# 283673      283673   1529267  2026-04-16        T20  Indian Premier League
# 283674      283674   1529267  2026-04-16        T20  Indian Premier League
# 283675      283675   1529267  2026-04-16        T20  Indian Premier League
# ...

# %%
out = ipl['batting_team'] == "Kolkata Knight Riders"
new_df = ipl[out]
new_df[['date','bowling_team']]
# Out:
#               date                 bowling_team
# 0       2008-04-18  Royal Challengers Bangalore
# 1       2008-04-18  Royal Challengers Bangalore
# 2       2008-04-18  Royal Challengers Bangalore
# 3       2008-04-18  Royal Challengers Bangalore
# 4       2008-04-18  Royal Challengers Bangalore
# ...            ...                          ...
# 283224  2026-04-14          Chennai Super Kings
# 283225  2026-04-14          Chennai Super Kings
# 283226  2026-04-14          Chennai Super Kings
# 283227  2026-04-14          Chennai Super Kings
# 283228  2026-04-14          Chennai Super Kings
#
# [31398 rows x 2 columns]

# %%
inn = ipl['innings'] == 2
new_df = ipl[inn]
new_df[['innings','team_balls']]
# Out:
#         innings  team_balls
# 124           2           1
# 125           2           1
# 126           2           2
# 127           2           3
# 128           2           4
# ...         ...         ...
# 283673        2          96
# 283674        2          97
# 283675        2          98
# 283676        2          98
# 283677        2          99
#
# [136510 rows x 2 columns]

# %%
csk = (ipl['innings'] == 1) & (ipl['batting_team'] == 'Chennai Super Kings')
again_new = ipl[csk]
again_new[['date','innings','batting_team']]
# Out:
#               date  innings         batting_team
# 225     2008-04-19        1  Chennai Super Kings
# 226     2008-04-19        1  Chennai Super Kings
# 227     2008-04-19        1  Chennai Super Kings
# 228     2008-04-19        1  Chennai Super Kings
# 229     2008-04-19        1  Chennai Super Kings
# ...            ...      ...                  ...
# 283099  2026-04-14        1  Chennai Super Kings
# 283100  2026-04-14        1  Chennai Super Kings
# 283101  2026-04-14        1  Chennai Super Kings
# 283102  2026-04-14        1  Chennai Super Kings
# 283103  2026-04-14        1  Chennai Super Kings
#
# [17349 rows x 3 columns]

# %%
percentage = (ipl['batting_team'] == 'Chennai Super Kings') == (ipl['innings'] == 1)
new_percent = (percentage.shape[0]/ipl.shape[0])*100
new_percent
# Out:
# 100.0

# %%
# adding a new column for a pre existing one
ipl['Country'] = 'India'
ipl.head()
# Out:
#    Unnamed: 0  match_id        date match_type             event_name  \
# 0      141607    335982  2008-04-18        T20  Indian Premier League
# 1      141608    335982  2008-04-18        T20  Indian Premier League
# 2      141609    335982  2008-04-18        T20  Indian Premier League
# 3      141610    335982  2008-04-18        T20  Indian Premier League
# 4      141611    335982  2008-04-18        T20  Indian Premier League
#
#    innings           batting_team                 bowling_team  over  ball  \
# 0        1  Kolkata Knight Riders  Royal Challengers Bangalore     0     1
# 1        1  Kolkata Knight Riders  Royal Challengers Bangalore     0     2
# 2        1  Kolkata Knight Riders  Royal Challengers Bangalore     0     3
# 3        1  Kolkata Knight Riders  Royal Challengers Bangalore     0     3
# 4        1  Kolkata Knight Riders  Royal Challengers Bangalore     0     4
#
#    ...  team_wicket new_batter  power_surge_start  batter_runs  batter_balls  \
# ...

# %%
students['college'] = 'Eye eye tea Bombay'
students.head()
# Out:
#     iq  marks  lpa             college
# 0  100     90    7  Eye eye tea Bombay
# 1  120     89   14  Eye eye tea Bombay
# 2   96     45   89  Eye eye tea Bombay
